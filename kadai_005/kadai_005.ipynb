# %%
'''
上辺：10cm
下辺：20cm
高さ：5cm

公式：台形の面積 =（上辺＋下辺）× 高さ ÷ 2

'''

number1=10
number2=20
number3=5

menseki=(number1+number2)*number3/2
print(f"{menseki}㎠")
# Out:
# 75.0㎠

# %%
number1=10
number2=20
number3=5

menseki=(number1+number2)*number3/2
print(str(menseki)+"㎠")
# Out:
# 75.0㎠
